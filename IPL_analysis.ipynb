# %% [markdown]
# ## Analyzing IPL Matches

# %%
# File location and type
file_location1 = "/FileStore/tables/ipl_ball_by_ball.csv"
file_location2 = "/FileStore/tables/ipl_matches.csv"
file_location3 = "/FileStore/tables/ipl_venue.csv"
file_type = "csv"

# %%
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df1 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location1)

df1.show(5)
# Out:
# +--------+------+-----+----+-------------+-------------+------------+------------+----------+----------+------------+---------+--------------+----------------+-------+-----------+--------------------+--------------+
# |match_id|inning|overs|ball|      batsman|  non_striker|      bowler|batsman_runs|extra_runs|total_runs|non_boundary|is_wicket|dismissal_kind|player_dismissed|fielder|extras_type|        batting_team|  bowling_team|
# +--------+------+-----+----+-------------+-------------+------------+------------+----------+----------+------------+---------+--------------+----------------+-------+-----------+--------------------+--------------+
# |  419157|     2|   16|   4|      V Kohli|R Vinay Kumar|CRD Fernando|           0|         0|         0|           0|        0|            NA|              NA|     NA|         NA|Royal Challengers...|Mumbai Indians|
# |  419157|     2|   16|   5|      V Kohli|R Vinay Kumar|CRD Fernando|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Royal Challengers...|Mumbai Indians|
# |  419157|     2|   16|   6|R Vinay Kumar|      V Kohli|CRD Fernando|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Royal Challengers...|Mumbai Indians|
# |  419157|     2|   17|   1|R Vinay Kumar|      V Kohli|   R McLaren|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Royal Challengers...|Mumbai Indians|
# |  419157|     2|   17|   2|      V Kohli|R Vinay Kumar|   R McLaren|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Royal Challengers...|Mumbai Indians|
# +--------+------+-----+----+-------------+-------------+------------+------------+----------+----------+------------+---------+--------------+----------------+-------+-----------+--------------------+--------------+
# only showing top 5 rows

# %%
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df2 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location2)

df2.show(5)
# Out:
# +--------+-------------------+---------------+--------+-------------+--------------------+--------------------+--------------------+-------------+--------------------+-------+-------------+----------+------+---------+--------------+
# |match_id|               date|player_of_match|venue_id|neutral_venue|               team1|               team2|         toss_winner|toss_decision|              winner| result|result_margin|eliminator|method|  umpire1|       umpire2|
# +--------+-------------------+---------------+--------+-------------+--------------------+--------------------+--------------------+-------------+--------------------+-------+-------------+----------+------+---------+--------------+
# |  335982|2008-04-18 00:00:00|    BB McCullum|      35|            0|Royal Challengers...|Kolkata Knight Ri...|Royal Challengers...|        field|Kolkata Knight Ri...|   runs|          140|         N|    NA|Asad Rauf|   RE Koertzen|
# |  335983|2008-04-19 00:00:00|     MEK Hussey|      31|            0|     Kings XI Punjab| Chennai Super Kings| Chennai Super Kings|          bat| Chennai Super Kings|   runs|           33|         N|    NA|MR Benson|    SL Shastri|
# |  335984|2008-04-19 00:00:00|    MF Maharoof|      27|            0|    Delhi Daredevils|    Rajasthan Royals|    Rajasthan Royals|          bat|    Delhi Daredevils|wickets|            9|         N|    NA|Aleem Dar|GA Pratapkumar|
# |  335985|2008-04-20 00:00:00|     MV Boucher|      14|            0|      Mumbai Indians|Royal Challengers...|      Mumbai Indians|          bat|Royal Challengers...|wickets|            5|         N|    NA| SJ Davis|     DJ Harper|
# |  335986|2008-04-20 00:00:00|      DJ Hussey|      15|            0|Kolkata Knight Ri...|     Deccan Chargers|     Deccan Chargers|          bat|Kolkata Knight Ri...|wickets|            5|         N|    NA|BF Bowden|   K Hariharan|
# +--------+-------------------+---------------+--------+-------------+--------------------+--------------------+--------------------+-------------+--------------------+-------+-------------+----------+------+---------+--------------+
# only showing top 5 rows

# %%
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df3 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location3)

df3.show(5)
# Out:
# +--------+--------------------+-------------+
# |venue_id|               venue|         city|
# +--------+--------------------+-------------+
# |       1|Dr. Y.S. Rajasekh...|Visakhapatnam|
# |       2|Sharjah Cricket S...|      Sharjah|
# |       3|JSCA Internationa...|       Ranchi|
# |       4|Saurashtra Cricke...|       Rajkot|
# |       5|Shaheed Veer Nara...|       Raipur|
# +--------+--------------------+-------------+
# only showing top 5 rows

# %%
spark.conf.set("spark.sql.legacy.allowCreatingManagedTableUsingNonemptyLocation","true")

permanent_table_name1 = "ipl_ball_by_ball"
permanent_table_name2 = "ipl_matches"
permanent_table_name3 = "ipl_venue"

df1.write.format("parquet").saveAsTable(permanent_table_name1)
df2.write.format("parquet").saveAsTable(permanent_table_name2)
df3.write.format("parquet").saveAsTable(permanent_table_name3)

# %%
# %sql
-- # A. Find the top 3 venues which hosted the most number of eliminator matches?

SELECT b.venue, COUNT(a.eliminator) AS eliminator_count
FROM ipl_matches a
JOIN ipl_venue b
ON a.venue_id == b.venue_id
WHERE a.eliminator = 'Y'
GROUP BY b.venue
LIMIT 3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>venue</th><th>eliminator_count</th></tr></thead><tbody><tr><td>Dubai International Cricket Stadium</td><td>3</td></tr><tr><td>Sardar Patel Stadium, Motera</td><td>1</td></tr><tr><td>Feroz Shah Kotla</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
-- # B. Return most number of catches taken by a player in IPL history?

SELECT fielder, COUNT(dismissal_kind) AS num_catches 
FROM ipl_ball_by_ball
WHERE fielder != 'NA' AND dismissal_kind = 'caught'
GROUP BY fielder
ORDER BY num_catches DESC
LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fielder</th><th>num_catches</th></tr></thead><tbody><tr><td>KD Karthik</td><td>118</td></tr><tr><td>MS Dhoni</td><td>113</td></tr><tr><td>AB de Villiers</td><td>103</td></tr><tr><td>SK Raina</td><td>99</td></tr><tr><td>RG Sharma</td><td>88</td></tr></tbody></table></div>

# %%
# %sql 
-- # C. Write a query to return a report for highest wicket taker in matches which were affected by Duckworth-Lewis’s method (D/L method).

SELECT a.bowler, COUNT(a.bowler) AS wicket_count 
FROM ipl_ball_by_ball a
JOIN ipl_matches b
ON a.match_id = b.match_id
WHERE b.method = 'D/L' AND a.is_wicket = 1
GROUP BY a.bowler
ORDER BY wicket_count DESC
LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>bowler</th><th>wicket_count</th></tr></thead><tbody><tr><td>R Ashwin</td><td>8</td></tr><tr><td>AB Dinda</td><td>8</td></tr><tr><td>MC Henriques</td><td>7</td></tr><tr><td>B Kumar</td><td>6</td></tr><tr><td>JD Unadkat</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
-- # D. Write a query to return a report for highest strike rate by a batsman in non powerplay overs(7-20 overs)
-- # Note: strike rate = (Total Runs scored/Total balls faced by player) *100, Make sure
-- # that balls faced by players should be legal delivery (not wide balls or no balls
-- total batsman runs

SELECT a.batsman, ((a.total_runs/b.balls_faced)*100) AS strike_rate 
FROM (
SELECT batsman, SUM(batsman_runs) AS total_runs FROM ipl_ball_by_ball
WHERE overs >6 
GROUP BY batsman) a
JOIN (
  SELECT batsman, COUNT(batsman) AS balls_faced FROM ipl_ball_by_ball
  WHERE extras_type == 'NA'
  GROUP BY batsman) b
ON a.batsman == b.batsman
ORDER BY strike_rate DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batsman</th><th>strike_rate</th></tr></thead><tbody><tr><td>B Stanlake</td><td>250.0</td></tr><tr><td>KMDN Kulasekara</td><td>250.0</td></tr><tr><td>Umar Gul</td><td>229.41176470588235</td></tr><tr><td>VRV Singh</td><td>200.0</td></tr><tr><td>RS Sodhi</td><td>200.0</td></tr><tr><td>AD Russell</td><td>181.71779141104295</td></tr><tr><td>TU Deshpande</td><td>175.0</td></tr><tr><td>I Malhotra</td><td>175.0</td></tr><tr><td>Abdul Samad</td><td>173.4375</td></tr><tr><td>BCJ Cutting</td><td>172.992700729927</td></tr></tbody></table></div>

# %%
# %sql

-- We can see from the results of previous query; some of the top names in the list did not make sense. That is because sometimes those who face less balls 
-- have high strike rate. In this query the I have set the balls faced parameter to greater than 30. And sure enough the results make much more sense

SELECT a.batsman, ((a.total_runs/b.balls_faced)*100) AS strike_rate 
FROM (
SELECT batsman, SUM(batsman_runs) AS total_runs FROM ipl_ball_by_ball
WHERE overs >6 
GROUP BY batsman) a
JOIN (
  SELECT batsman, COUNT(batsman) AS balls_faced FROM ipl_ball_by_ball
  WHERE extras_type == 'NA'
  GROUP BY batsman
  HAVING balls_faced > 30) b
ON a.batsman == b.batsman
ORDER BY strike_rate DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batsman</th><th>strike_rate</th></tr></thead><tbody><tr><td>AD Russell</td><td>181.71779141104295</td></tr><tr><td>Abdul Samad</td><td>173.4375</td></tr><tr><td>BCJ Cutting</td><td>172.992700729927</td></tr><tr><td>CR Brathwaite</td><td>169.1588785046729</td></tr><tr><td>K Gowtham</td><td>164.8148148148148</td></tr><tr><td>LJ Wright</td><td>164.40677966101697</td></tr><tr><td>JC Archer</td><td>163.8655462184874</td></tr><tr><td>HH Pandya</td><td>160.53268765133174</td></tr><tr><td>KK Cooper</td><td>159.0909090909091</td></tr><tr><td>Rashid Khan</td><td>156.17977528089887</td></tr></tbody></table></div>

# %%
# %sql 

-- # E. Write a query to return a report for highest extra runs in a venue (stadium, city).


SELECT venue, SUM(extra_runs) AS extras
FROM ipl_ball_by_ball a
JOIN ipl_matches b
ON a.match_id == b.match_id
JOIN ipl_venue c
ON b.venue_id == c.venue_id
GROUP BY venue
ORDER BY extras DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>venue</th><th>extras</th></tr></thead><tbody><tr><td>M.Chinnaswamy Stadium</td><td>1355</td></tr><tr><td>Wankhede Stadium</td><td>1232</td></tr><tr><td>Eden Gardens</td><td>1215</td></tr><tr><td>Feroz Shah Kotla</td><td>1114</td></tr><tr><td>MA Chidambaram Stadium, Chepauk</td><td>905</td></tr><tr><td>Rajiv Gandhi International Stadium, Uppal</td><td>900</td></tr><tr><td>Sawai Mansingh Stadium</td><td>791</td></tr><tr><td>Punjab Cricket Association Stadium, Mohali</td><td>566</td></tr><tr><td>Dubai International Cricket Stadium</td><td>492</td></tr><tr><td>Sheikh Zayed Stadium</td><td>387</td></tr><tr><td>Dr DY Patil Sports Academy</td><td>320</td></tr><tr><td>Maharashtra Cricket Association Stadium</td><td>315</td></tr><tr><td>Sharjah Cricket Stadium</td><td>287</td></tr><tr><td>Kingsmead</td><td>277</td></tr><tr><td>Punjab Cricket Association IS Bindra Stadium, Mohali</td><td>271</td></tr><tr><td>Brabourne Stadium</td><td>246</td></tr><tr><td>Subrata Roy Sahara Stadium</td><td>237</td></tr><tr><td>SuperSport Park</td><td>213</td></tr><tr><td>Himachal Pradesh Cricket Association Stadium</td><td>177</td></tr><tr><td>Sardar Patel Stadium, Motera</td><td>175</td></tr><tr><td>Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium</td><td>161</td></tr><tr><td>Holkar Cricket Stadium</td><td>137</td></tr><tr><td>Saurashtra Cricket Association Stadium</td><td>131</td></tr><tr><td>St George's Park</td><td>129</td></tr><tr><td>Newlands</td><td>112</td></tr><tr><td>New Wanderers Stadium</td><td>108</td></tr><tr><td>JSCA International Stadium Complex</td><td>100</td></tr><tr><td>Barabati Stadium</td><td>83</td></tr><tr><td>Nehru Stadium</td><td>77</td></tr><tr><td>Shaheed Veer Narayan Singh International Stadium</td><td>77</td></tr><tr><td>Green Park</td><td>62</td></tr><tr><td>Vidarbha Cricket Association Stadium, Jamtha</td><td>60</td></tr><tr><td>Buffalo Park</td><td>57</td></tr><tr><td>OUTsurance Oval</td><td>41</td></tr><tr><td>De Beers Diamond Oval</td><td>39</td></tr></tbody></table></div>

# %%
# %sql 

-- # F. Write a query to return a report for the cricketers with the most number of players of
-- # the match award in neutral venues.

SELECT player_of_match, COUNT(player_of_match) AS count
FROM ipl_matches
WHERE neutral_venue = 1
GROUP BY player_of_match
ORDER BY count DESC
LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>player_of_match</th><th>count</th></tr></thead><tbody><tr><td>YK Pathan</td><td>3</td></tr><tr><td>JH Kallis</td><td>3</td></tr><tr><td>JP Duminy</td><td>3</td></tr><tr><td>GJ Maxwell</td><td>3</td></tr><tr><td>KC Sangakkara</td><td>2</td></tr></tbody></table></div>

# %%
# %sql

-- # G. Write a query to get a list of top 10 players with the highest batting average Note:
-- # Batting average is the total number of runs scored divided by the number of times
-- # they have been out (Make sure to include run outs (on non-striker end) as valid
-- # out while calculating average).

SELECT a.batsman, a.runs/b.dismissals AS average
FROM (SELECT batsman, SUM(batsman_runs) AS runs FROM ipl_ball_by_ball
GROUP BY batsman) a
JOIN (SELECT batsman, COUNT(player_dismissed) AS dismissals FROM ipl_ball_by_ball
WHERE player_dismissed != 'NA'
GROUP BY batsman
) b
ON a.batsman == b.batsman
ORDER BY average DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batsman</th><th>average</th></tr></thead><tbody><tr><td>Iqbal Abdulla</td><td>88.0</td></tr><tr><td>RD Gaikwad</td><td>68.0</td></tr><tr><td>MN van Wyk</td><td>55.666666666666664</td></tr><tr><td>PD Collingwood</td><td>50.75</td></tr><tr><td>HM Amla</td><td>44.38461538461539</td></tr><tr><td>LH Ferguson</td><td>44.0</td></tr><tr><td>KL Rahul</td><td>42.693548387096776</td></tr><tr><td>AB de Villiers</td><td>42.53508771929825</td></tr><tr><td>DA Warner</td><td>41.698412698412696</td></tr><tr><td>JP Duminy</td><td>41.40816326530612</td></tr></tbody></table></div>

# %%
# %sql
-- # H. Write a query to find out who has officiated (as an umpire) the most
-- # number of matches in IPL.

SELECT a.umpire1 AS umpire, (a.count1 + b.count2) AS total
FROM (SELECT umpire1, COUNT(umpire1) AS count1 FROM ipl_matches
GROUP BY umpire1) a
JOIN
(SELECT umpire2, count(umpire2) AS count2 FROM ipl_matches
GROUP BY umpire2) b
ON a.umpire1 == b.umpire2
ORDER BY total DESC
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>umpire</th><th>total</th></tr></thead><tbody><tr><td>S Ravi</td><td>121</td></tr></tbody></table></div>

# %%
# %sql

-- # I. Find venue details of the match where V Kohli scored his highest individual runs in
-- # IPL.

SELECT DISTINCT d.match_id, d.runs, c.venue
FROM ipl_ball_by_ball a
JOIN ipl_matches b
ON a.match_id == b.match_id
JOIN ipl_venue c
ON b.venue_id == c.venue_id
JOIN (
  SELECT CAST(match_id AS string), sum(batsman_runs) AS runs FROM ipl_ball_by_ball
  WHERE batsman == 'V Kohli'
  GROUP BY match_id
  ORDER BY runs DESC) d
ON a.match_id = d.match_id
ORDER BY runs DESC
LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>match_id</th><th>runs</th><th>venue</th></tr></thead><tbody><tr><td>980999</td><td>113</td><td>M.Chinnaswamy Stadium</td></tr><tr><td>980987</td><td>109</td><td>M.Chinnaswamy Stadium</td></tr><tr><td>980969</td><td>108</td><td>M.Chinnaswamy Stadium</td></tr><tr><td>1178410</td><td>100</td><td>Eden Gardens</td></tr><tr><td>980937</td><td>100</td><td>Saurashtra Cricket Association Stadium</td></tr></tbody></table></div>

# %%
# %sql 
-- # J. Creative Case study:
-- # Please analyze how winning/losing tosses can impact a match and it's result?
-- # (Bonus for Visualization here)


SELECT  toss_winner, count(toss_winner) AS match_toss_win
FROM ipl_matches
WHERE toss_winner = winner
GROUP BY toss_winner
ORDER BY match_toss_win DESC;

-- The analysis of this question is divided into multiple cells.
-- (1/n)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>toss_winner</th><th>match_toss_win</th></tr></thead><tbody><tr><td>Mumbai Indians</td><td>61</td></tr><tr><td>Chennai Super Kings</td><td>61</td></tr><tr><td>Kolkata Knight Riders</td><td>55</td></tr><tr><td>Rajasthan Royals</td><td>44</td></tr><tr><td>Royal Challengers Bangalore</td><td>43</td></tr><tr><td>Kings XI Punjab</td><td>36</td></tr><tr><td>Delhi Daredevils</td><td>35</td></tr><tr><td>Sunrisers Hyderabad</td><td>29</td></tr><tr><td>Deccan Chargers</td><td>19</td></tr><tr><td>Delhi Capitals</td><td>10</td></tr><tr><td>Gujarat Lions</td><td>10</td></tr><tr><td>Rising Pune Supergiant</td><td>5</td></tr><tr><td>Kochi Tuskers Kerala</td><td>4</td></tr><tr><td>Rising Pune Supergiants</td><td>3</td></tr><tr><td>Pune Warriors</td><td>3</td></tr></tbody></table></div>

# %%
# %sql

--  this query shows the teams who have lost the most matches where they won the toss

SELECT  toss_winner, count(toss_winner) AS match_toss_win
FROM ipl_matches
WHERE toss_winner != winner
GROUP BY toss_winner
ORDER BY match_toss_win DESC;

-- (2/n)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>toss_winner</th><th>match_toss_win</th></tr></thead><tbody><tr><td>Kings XI Punjab</td><td>49</td></tr><tr><td>Delhi Daredevils</td><td>45</td></tr><tr><td>Mumbai Indians</td><td>45</td></tr><tr><td>Royal Challengers Bangalore</td><td>44</td></tr><tr><td>Rajasthan Royals</td><td>43</td></tr><tr><td>Kolkata Knight Riders</td><td>43</td></tr><tr><td>Chennai Super Kings</td><td>36</td></tr><tr><td>Sunrisers Hyderabad</td><td>28</td></tr><tr><td>Deccan Chargers</td><td>24</td></tr><tr><td>Pune Warriors</td><td>17</td></tr><tr><td>Delhi Capitals</td><td>10</td></tr><tr><td>Gujarat Lions</td><td>5</td></tr><tr><td>Kochi Tuskers Kerala</td><td>4</td></tr><tr><td>Rising Pune Supergiants</td><td>4</td></tr><tr><td>Rising Pune Supergiant</td><td>1</td></tr></tbody></table></div>

# %%
# %sql

SELECT winner, COUNT(winner) AS wins 
FROM ipl_matches 
GROUP BY winner
ORDER BY wins DESC

-- This graph shows us that the teams who won most with winning toss and the teams who have most overall wins are the same. i.e. Mumbai Indians and CSK. What this 
-- shows us that toss do not have significant effect on match result

-- (3/n)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>winner</th><th>wins</th></tr></thead><tbody><tr><td>Mumbai Indians</td><td>120</td></tr><tr><td>Chennai Super Kings</td><td>106</td></tr><tr><td>Kolkata Knight Riders</td><td>99</td></tr><tr><td>Royal Challengers Bangalore</td><td>91</td></tr><tr><td>Kings XI Punjab</td><td>88</td></tr><tr><td>Rajasthan Royals</td><td>81</td></tr><tr><td>Delhi Daredevils</td><td>67</td></tr><tr><td>Sunrisers Hyderabad</td><td>66</td></tr><tr><td>Deccan Chargers</td><td>29</td></tr><tr><td>Delhi Capitals</td><td>19</td></tr><tr><td>Gujarat Lions</td><td>13</td></tr><tr><td>Pune Warriors</td><td>12</td></tr><tr><td>Rising Pune Supergiant</td><td>10</td></tr><tr><td>Kochi Tuskers Kerala</td><td>6</td></tr><tr><td>Rising Pune Supergiants</td><td>5</td></tr><tr><td>NA</td><td>4</td></tr></tbody></table></div>

# %%
# %sql

SELECT COUNT(winner)
FROM ipl_matches 
WHERE toss_winner = winner

-- This shows how may times the toss winning team has won the match.

-- (4/n)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(winner)</th></tr></thead><tbody><tr><td>418</td></tr></tbody></table></div>

# %%
# %sql

SELECT COUNT(winner)
FROM ipl_matches 
WHERE toss_winner != winner

-- This shows how may times the toss winning team has lost the match. As we can see there is difference but it is not very big. We can definately conclude that 
-- toss winning is beneficial but not be all end all for the match

-- (5/5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(winner)</th></tr></thead><tbody><tr><td>398</td></tr></tbody></table></div>

# %%
import sqlite3
conn = sqlite3.connect("ipl.db")
c = conn.cursor()

# %%
# Converting tables to pandas so they can be loaded into sqlite database

a = sqlContext.sql("select * from ipl_matches").toPandas()
b = sqlContext.sql("select * from ipl_ball_by_ball").toPandas()
d = sqlContext.sql("select * from ipl_venue").toPandas()

# %%
# I will load the data from existing tables to sqlite database

a.to_sql(name = 'ipl_matches', con = conn, schema = a.columns ,if_exists = 'replace')
b.to_sql(name = 'ipl_ball_by_ball', con = conn, schema = b.columns ,if_exists = 'replace')
d.to_sql(name = 'ipl_venue', con = conn, schema = d.columns ,if_exists = 'replace' )

# %%
# Test

c.execute("select a.match_id, a.overs, a.batsman \
from ipl_ball_by_ball a")
c.fetchall()
# Out:
# Out[9]: [(419157, 16, 'V Kohli'),
#  (419157, 16, 'V Kohli'),
#  (419157, 16, 'R Vinay Kumar'),
#  (419157, 17, 'R Vinay Kumar'),
#  (419157, 17, 'V Kohli'),
#  (419157, 17, 'R Vinay Kumar'),
#  (419157, 17, 'R Vinay Kumar'),
#  (419157, 17, 'R Vinay Kumar'),
#  (419157, 17, 'V Kohli'),
#  (419157, 18, 'V Kohli'),
#  (419157, 18, 'V Kohli'),
#  (419157, 18, 'R Vinay Kumar'),
#  (419157, 18, 'R Vinay Kumar'),
#  (419157, 18, 'Pankaj Singh'),
#  (419157, 18, 'R Vinay Kumar'),
#  (419157, 18, 'Pankaj Singh'),
#  (419157, 19, 'A Kumble'),
#  (419157, 0, 'R McLaren'),
#  (419157, 0, 'SR Tendulkar'),
#  (419157, 0, 'SR Tendulkar'),
#  (419157, 0, 'R McLaren'),
#  (419157, 0, 'SR Tendulkar'),
#  (419157, 0, 'MK Pandey'),
#  (419157, 0, 'MK Pandey'),
#  (419157, 0, 'MK Pandey'),
#  (419157, 0, 'MK Pandey'),
#  (419157, 0, 'MK Pandey'),
#  (419157, 0, 'JH Kallis'),
#  (419157, 1, 'JH Kallis'),
#  (419157, 1, 'JH Kallis'),
#  (419157, 1, 'JH Kallis'),
#  (419157, 1, 'MK Pandey'),
#  (419157, 1, 'MK Pandey'),
#  (419157, 1, 'MK Pandey'),
#  (419157, 2, 'JH Kallis'),
#  (419157, 2, 'JH Kallis'),
#  (419157, 2, 'MK Pandey'),
#  (419157, 2, 'MK Pandey'),
#  (419157, 2, 'MK Pandey'),
#  (419157, 2, 'JH Kallis'),
#  (419157, 3, 'JH Kallis'),
#  (419157, 3, 'JH Kallis'),
#  (419157, 3, 'MK Pandey'),
#  (419157, 3, 'JH Kallis'),
#  (419157, 3, 'JH Kallis'),
#  (419157, 3, 'MK Pandey'),
#  (419157, 4, 'MK Pandey'),
#  (419157, 4, 'MK Pandey'),
#  (419157, 4, 'MK Pandey'),
#  (419157, 4, 'MK Pandey'),
#  (419157, 4, 'MK Pandey'),
#  (419157, 4, 'JH Kallis'),
#  (419157, 5, 'KP Pietersen'),
#  (419157, 5, 'JH Kallis'),
#  (419157, 5, 'JH Kallis'),
#  (419157, 5, 'JH Kallis'),
#  (419157, 5, 'R Dravid'),
#  (336007, 9, 'MS Dhoni'),
#  (419157, 5, 'KP Pietersen'),
#  (336007, 9, 'MS Dhoni'),
#  (419157, 6, 'R Dravid'),
#  (336007, 9, 'MS Dhoni'),
#  (419157, 6, 'KP Pietersen'),
#  (336007, 9, 'MS Dhoni'),
#  (419157, 6, 'KP Pietersen'),
#  (336007, 9, 'MS Dhoni'),
#  (419157, 6, 'KP Pietersen'),
#  (1216504, 19, 'EJG Morgan'),
#  (1216505, 6, 'V Kohli'),
#  (1216505, 7, 'D Padikkal'),
#  (1216505, 6, 'D Padikkal'),
#  (1216505, 7, 'V Kohli'),
#  (1216505, 7, 'D Padikkal'),
#  (1216505, 7, 'V Kohli'),
#  (1216505, 7, 'D Padikkal'),
#  (1216505, 8, 'D Padikkal'),
#  (1216505, 9, 'D Padikkal'),
#  (1216505, 9, 'V Kohli'),
#  (1216505, 9, 'V Kohli'),
#  (1216505, 9, 'D Padikkal'),
#  (1216505, 9, 'V Kohli'),
#  (1216505, 9, 'D Padikkal'),
#  (1216505, 7, 'V Kohli'),
#  (1216505, 8, 'V Kohli'),
#  (1216505, 8, 'D Padikkal'),
#  (1216505, 8, 'D Padikkal'),
#  (1216505, 8, 'V Kohli'),
#  (1216505, 8, 'V Kohli'),
#  (1216505, 11, 'D Padikkal'),
#  (1216505, 11, 'D Padikkal'),
#  (1216505, 11, 'V Kohli'),
#  (1216505, 11, 'D Padikkal'),
#  (1216505, 11, 'V Kohli'),
#  (1216505, 11, 'V Kohli'),
#  (1216505, 12, 'D Padikkal'),
#  (1216505, 10, 'V Kohli'),
#  (1216505, 10, 'V Kohli'),
#  (1216505, 10, 'V Kohli'),
#  (1216505, 10, 'D Padikkal'),
#  (1216505, 10, 'V Kohli'),
#  (1216505, 10, 'D Padikkal'),
#  (1216505, 6, 'D Padikkal'),
#  (1216505, 0, 'JR Philippe'),
#  (1216505, 0, 'JR Philippe'),
#  (1216505, 0, 'D Padikkal'),
#  (1216505, 0, 'JR Philippe'),
#  (1216505, 0, 'JR Philippe'),
#  (1216505, 0, 'JR Philippe'),
#  (1216505, 1, 'D Padikkal'),
#  (1216505, 1, 'JR Philippe'),
#  (1216505, 1, 'JR Philippe'),
#  (1216505, 1, 'D Padikkal'),
#  (1216505, 1, 'JR Philippe'),
#  (1216505, 1, 'D Padikkal'),
#  (1216505, 2, 'JR Philippe'),
#  (1216505, 2, 'JR Philippe'),
#  (1216505, 2, 'JR Philippe'),
#  (1216505, 2, 'JR Philippe'),
#  (1216505, 2, 'JR Philippe'),
#  (1216505, 2, 'JR Philippe'),
#  (1216505, 2, 'D Padikkal'),
#  (1216505, 3, 'JR Philippe'),
#  (1216505, 3, 'D Padikkal'),
#  (1216505, 3, 'D Padikkal'),
#  (1216505, 3, 'D Padikkal'),
#  (1216505, 3, 'JR Philippe'),
#  (419157, 6, 'R Dravid'),
#  (1216505, 3, 'JR Philippe'),
#  (419157, 6, 'KP Pietersen'),
#  (1216505, 4, 'JR Philippe'),
#  (419157, 7, 'KP Pietersen'),
#  (1216505, 4, 'D Padikkal'),
#  (419157, 7, 'R Dravid'),
#  (1216505, 4, 'D Padikkal'),
#  (419157, 7, 'R Dravid'),
#  (1082635, 1, 'PA Patel'),
#  (1082635, 1, 'LMP Simmons'),
#  (1082635, 1, 'PA Patel'),
#  (1082635, 1, 'PA Patel'),
#  (1082635, 1, 'LMP Simmons'),
#  (1082635, 1, 'PA Patel'),
#  (1082635, 2, 'PA Patel'),
#  (1082635, 2, 'LMP Simmons'),
#  (1082635, 2, 'LMP Simmons'),
#  (1082635, 2, 'PA Patel'),
#  (1082635, 2, 'LMP Simmons'),
#  (1082635, 2, 'PA Patel'),
#  (1082635, 3, 'LMP Simmons'),
#  (1082635, 3, 'LMP Simmons'),
#  (1082635, 3, 'LMP Simmons'),
#  (1082635, 3, 'LMP Simmons'),
#  (1082635, 3, 'LMP Simmons'),
#  (1082635, 3, 'LMP Simmons'),
#  (1082635, 4, 'LMP Simmons'),
#  (1082635, 4, 'LMP Simmons'),
#  (1082635, 4, 'PA Patel'),
#  (1082635, 4, 'PA Patel'),
#  (1082635, 4, 'LMP Simmons'),
#  (1082635, 4, 'PA Patel'),
#  (1082635, 5, 'PA Patel'),
#  (1082635, 5, 'LMP Simmons'),
#  (1082635, 5, 'LMP Simmons'),
#  (1082635, 5, 'LMP Simmons'),
#  (1082635, 5, 'PA Patel'),
#  (1082635, 5, 'PA Patel'),
#  (1082635, 5, 'PA Patel'),
#  (1082635, 6, 'LMP Simmons'),
#  (1082635, 6, 'PA Patel'),
#  (1082635, 6, 'LMP Simmons'),
#  (1082635, 6, 'LMP Simmons'),
#  (1082635, 6, 'PA Patel'),
#  (1082635, 6, 'LMP Simmons'),
#  (829727, 2, 'S Dhawan'),
#  (829727, 1, 'DA Warner'),
#  (829727, 2, 'S Dhawan'),
#  (829727, 2, 'S Dhawan'),
#  (829727, 2, 'S Dhawan'),
#  (829727, 2, 'S Dhawan'),
#  (829727, 2, 'DA Warner'),
#  (829727, 3, 'S Dhawan'),
#  (829727, 3, 'DA Warner'),
#  (829727, 3, 'DA Warner'),
#  (829727, 3, 'DA Warner'),
#  (829727, 3, 'S Dhawan'),
#  (829727, 3, 'S Dhawan'),
#  (829727, 4, 'DA Warner'),
#  (829727, 2, 'S Dhawan'),
#  (829727, 4, 'DA Warner'),
#  (829727, 4, 'KL Rahul'),
#  (829727, 4, 'KL Rahul'),
#  (829727, 4, 'KL Rahul'),
#  (829727, 4, 'KL Rahul'),
#  (829727, 5, 'KL Rahul'),
#  (829727, 5, 'EJG Morgan'),
#  (829727, 5, 'EJG Morgan'),
#  (829727, 5, 'EJG Morgan'),
#  (829727, 5, 'EJG Morgan'),
#  (829727, 5, 'EJG Morgan'),
#  (829727, 6, 'NV Ojha'),
#  (829727, 4, 'DA Warner'),
#  (829727, 0, 'DA Warner'),
#  (829727, 0, 'DA Warner'),
#  (829727, 0, 'S Dhawan'),
#  (829727, 0, 'S Dhawan'),
#  (548379, 5, 'MEK Hussey'),
#  (548379, 5, 'S Badrinath'),
#  (548379, 5, 'MEK Hussey'),
#  (548379, 6, 'MEK Hussey'),
#  (548379, 6, 'MEK Hussey'),
#  (548379, 6, 'S Badrinath'),
#  (548379, 6, 'S Badrinath'),
#  (548379, 6, 'S Badrinath'),
#  (548379, 6, 'S Badrinath'),
#  (548379, 7, 'S Badrinath'),
#  (548379, 7, 'S Badrinath'),
#  (548379, 7, 'MEK Hussey'),
#  (548379, 7, 'MEK Hussey'),
#  (548379, 7, 'S Badrinath'),
#  (548379, 7, 'MEK Hussey'),
#  (548379, 8, 'S Badrinath'),
#  (548379, 8, 'S Badrinath'),
#  (548379, 8, 'S Badrinath'),
#  (548379, 8, 'S Badrinath'),
#  (548379, 8, 'S Badrinath'),
#  (548379, 8, 'S Badrinath'),
#  (548379, 9, 'MEK Hussey'),
#  (548379, 9, 'MEK Hussey'),
#  (548379, 9, 'S Badrinath'),
#  (548379, 9, 'S Badrinath'),
#  (548379, 9, 'S Badrinath'),
#  (548379, 9, 'S Badrinath'),
#  (548379, 10, 'S Badrinath'),
#  (1082635, 7, 'LMP Simmons'),
#  (1082635, 7, 'LMP Simmons'),
#  (1082635, 7, 'PA Patel'),
#  (1082635, 7, 'LMP Simmons'),
#  (1082635, 7, 'LMP Simmons'),
#  (1082635, 7, 'PA Patel'),
#  (1082635, 8, 'LMP Simmons'),
#  (1082635, 8, 'PA Patel'),
#  (1082635, 8, 'PA Patel'),
#  (1082635, 8, 'PA Patel'),
#  (1082635, 8, 'KA Pollard'),
#  (1082635, 8, 'KA Pollard'),
#  (1082635, 9, 'LMP Simmons'),
#  (1082635, 9, 'LMP Simmons'),
#  (1082635, 9, 'LMP Simmons'),
#  (1082635, 9, 'LMP Simmons'),
#  (1082635, 9, 'LMP Simmons'),
#  (1082635, 9, 'KA Pollard'),
#  (1082635, 10, 'LMP Simmons'),
#  (1082635, 10, 'LMP Simmons'),
#  (1082635, 10, 'KA Pollard'),
#  (1082635, 10, 'KA Pollard'),
#  (1082635, 9, 'Mohammed Shami'),
#  (1082635, 9, 'A Mishra'),
#  (1082635, 10, 'A Mishra'),
#  (1082635, 10, 'Mohammed Shami'),
#  (1082635, 10, 'Mohammed Shami'),
#  (1082635, 10, 'Mohammed Shami'),
#  (1082635, 10, 'A Mishra'),
#  (1082635, 10, 'Z Khan'),
#  (1082635, 11, 'A Mishra'),
#  (1082635, 11, 'A Mishra'),
#  (1082635, 11, 'A Mishra'),
#  (1082635, 11, 'Z Khan'),
#  (1082635, 11, 'A Mishra'),
#  (1216505, 4, 'D Padikkal'),
#  (1216505, 4, 'D Padikkal'),
#  (1216505, 4, 'V Kohli'),
#  (1216505, 5, 'V Kohli'),
#  (1216505, 5, 'V Kohli'),
#  (1216505, 5, 'V Kohli'),
#  (1216505, 5, 'V Kohli'),
#  (1216505, 5, 'D Padikkal'),
#  (1216505, 5, 'D Padikkal'),
#  (1216505, 6, 'V Kohli'),
#  (548379, 0, 'M Vijay'),
#  (548379, 0, 'M Vijay'),
#  (548379, 0, 'M Vijay'),
#  (548379, 0, 'M Vijay'),
#  (548379, 0, 'MEK Hussey'),
#  (548379, 0, 'MEK Hussey'),
#  (548379, 1, 'M Vijay'),
#  (548379, 1, 'SK Raina'),
#  (548379, 1, 'S Badrinath'),
#  (548379, 1, 'S Badrinath'),
#  (548379, 1, 'S Badrinath'),
#  (548379, 1, 'S Badrinath'),
#  (548379, 1, 'S Badrinath'),
#  (548379, 2, 'MEK Hussey'),
#  (548379, 2, 'MEK Hussey'),
#  (548379, 2, 'MEK Hussey'),
#  (548379, 2, 'MEK Hussey'),
#  (548379, 2, 'MEK Hussey'),
#  (548379, 2, 'MEK Hussey'),
#  (548379, 3, 'S Badrinath'),
#  (548379, 3, 'S Badrinath'),
#  (548379, 3, 'S Badrinath'),
#  (548379, 3, 'S Badrinath'),
#  (548379, 3, 'S Badrinath'),
#  (548379, 3, 'MEK Hussey'),
#  (548379, 4, 'MEK Hussey'),
#  (548379, 4, 'MEK Hussey'),
#  (548379, 4, 'MEK Hussey'),
#  (548379, 4, 'MEK Hussey'),
#  (548379, 4, 'MEK Hussey'),
#  (548379, 4, 'MEK Hussey'),
#  (548379, 5, 'S Badrinath'),
#  (548379, 5, 'S Badrinath'),
#  (548379, 5, 'MEK Hussey'),
#  (336007, 10, 'SK Raina'),
#  (336007, 10, 'MS Dhoni'),
#  (336007, 10, 'MS Dhoni'),
#  (336007, 10, 'MS Dhoni'),
#  (336007, 10, 'MS Dhoni'),
#  (336007, 10, 'MS Dhoni'),
#  (336007, 10, 'MS Dhoni'),
#  (336007, 11, 'SK Raina'),
#  (336007, 11, 'SK Raina'),
#  (336007, 11, 'SK Raina'),
#  (336007, 11, 'SK Raina'),
#  (336007, 11, 'MS Dhoni'),
#  (336007, 11, 'SK Raina'),
#  (336007, 12, 'SK Raina'),
#  (336007, 12, 'MS Dhoni'),
#  (336007, 12, 'MS Dhoni'),
#  (336007, 12, 'MS Dhoni'),
#  (336007, 12, 'SK Raina'),
#  (336007, 12, 'MS Dhoni'),
#  (336007, 13, 'MS Dhoni'),
#  (336007, 13, 'MS Dhoni'),
#  (336007, 13, 'SK Raina'),
#  (336007, 13, 'JA Morkel'),
#  (336007, 13, 'JA Morkel'),
#  (336007, 13, 'JA Morkel'),
#  (336007, 14, 'MS Dhoni'),
#  (336007, 14, 'MS Dhoni'),
#  (336007, 14, 'MS Dhoni'),
#  (336007, 14, 'JA Morkel'),
#  (336007, 14, 'MS Dhoni'),
#  (336007, 14, 'Joginder Sharma'),
#  (336007, 15, 'JA Morkel'),
#  (336007, 15, 'Joginder Sharma'),
#  (336007, 15, 'JA Morkel'),
#  (336007, 15, 'Joginder Sharma'),
#  (336007, 15, 'Joginder Sharma'),
#  (1216505, 15, 'D Padikkal'),
#  (1216505, 15, 'CH Morris'),
#  (1216505, 15, 'CH Morris'),
#  (1216505, 16, 'AB de Villiers'),
#  (1216505, 16, 'S Dube'),
#  (1216505, 16, 'S Dube'),
#  (1216505, 16, 'S Dube'),
#  (1216505, 16, 'AB de Villiers'),
#  (1216505, 16, 'AB de Villiers'),
#  (1216505, 17, 'AB de Villiers'),
#  (1216505, 17, 'AB de Villiers'),
#  (1216505, 17, 'S Dube'),
#  (1216505, 17, 'S Dube'),
#  (1216505, 17, 'S Dube'),
#  (1216505, 17, 'S Dube'),
#  (1216505, 18, 'AB de Villiers'),
#  (1216505, 18, 'AB de Villiers'),
#  (1216505, 18, 'S Dube'),
#  (1216505, 18, 'S Dube'),
#  (1216505, 18, 'S Dube'),
#  (1216505, 18, 'S Dube'),
#  (1216505, 19, 'AB de Villiers'),
#  (1216505, 19, 'AB de Villiers'),
#  (1216505, 19, 'I Udana'),
#  (1216505, 19, 'I Udana'),
#  (1216505, 19, 'Washington Sundar'),
#  (1216505, 19, 'Shahbaz Ahmed'),
#  (1216505, 0, 'PP Shaw'),
#  (1216505, 0, 'S Dhawan'),
#  (1216505, 0, 'S Dhawan'),
#  (1216505, 0, 'S Dhawan'),
#  (1216505, 0, 'S Dhawan'),
#  (1216505, 14, 'AM Rahane'),
#  (1216505, 14, 'AM Rahane'),
#  (1216505, 14, 'AM Rahane'),
#  (1216505, 15, 'AM Rahane'),
#  (1216505, 15, 'SS Iyer'),
#  (1216505, 15, 'AM Rahane'),
#  (1216505, 15, 'AM Rahane'),
#  (1216505, 15, 'SS Iyer'),
#  (1216505, 15, 'AM Rahane'),
#  (1216505, 16, 'AM Rahane'),
#  (1216505, 16, 'SS Iyer'),
#  (1216505, 16, 'SS Iyer'),
#  (1216505, 16, 'RR Pant'),
#  (1216505, 16, 'AM Rahane'),
#  (1216505, 16, 'RR Pant'),
#  (1216505, 16, 'AM Rahane'),
#  (1216505, 17, 'AM Rahane'),
#  (1216505, 17, 'AM Rahane'),
#  (1216505, 17, 'MP Stoinis'),
#  (1216505, 17, 'RR Pant'),
#  (1216505, 17, 'RR Pant'),
#  (1216505, 17, 'MP Stoinis'),
#  (1216505, 18, 'RR Pant'),
#  (1216505, 18, 'RR Pant'),
#  (1216505, 18, 'MP Stoinis'),
#  (1216505, 12, 'S Dhawan'),
#  (1216505, 12, 'AM Rahane'),
#  (1216505, 12, 'AM Rahane'),
#  (1216505, 12, 'S Dhawan'),
#  (1216505, 12, 'SS Iyer'),
#  (1216505, 18, 'RR Pant'),
#  (1216505, 18, 'MP Stoinis'),
#  (829727, 3, 'AM Rahane'),
#  (1216505, 18, 'MP Stoinis'),
#  (829727, 4, 'SV Samson'),
#  (419158, 3, 'NV Ojha'),
#  (1216505, 18, 'MP Stoinis'),
#  (829727, 4, 'SV Samson'),
#  (419158, 3, 'SR Watson'),
#  (1216505, 18, 'RR Pant'),
#  (829727, 4, 'SV Samson'),
#  (419158, 4, 'SR Watson'),
#  (1216506, 7, 'KL Rahul'),
#  (829727, 4, 'AM Rahane'),
#  (419158, 4, 'SR Watson'),
#  (1216506, 8, 'CH Gayle'),
#  (829727, 4, 'AM Rahane'),
#  (419158, 4, 'SR Watson'),
#  (1216506, 8, 'KL Rahul'),
#  (829727, 4, 'SV Samson'),
#  (419158, 4, 'SR Watson'),
#  (1216506, 8, 'KL Rahul'),
#  (829727, 4, 'SV Samson'),
#  (419158, 4, 'SR Watson'),
#  (1216506, 8, 'N Pooran'),
#  (829727, 5, 'AM Rahane'),
#  (419158, 4, 'SR Watson'),
#  (1216506, 8, 'N Pooran'),
#  (829727, 5, 'AM Rahane'),
#  (419158, 5, 'NV Ojha'),
#  (1216506, 8, 'N Pooran'),
#  (829727, 5, 'AM Rahane'),
#  (419158, 5, 'SR Watson'),
#  (1216506, 9, 'CH Gayle'),
#  (829727, 6, 'NV Ojha'),
#  (419158, 5, 'SR Watson'),
#  (1216506, 7, 'CH Gayle'),
#  (829727, 6, 'NV Ojha'),
#  (336008, 13, 'SK Warne'),
#  (336008, 13, 'SA Asnodkar'),
#  (336008, 13, 'SA Asnodkar'),
#  (336008, 13, 'SA Asnodkar'),
#  (336008, 13, 'Sohail Tanvir'),
#  (336008, 13, 'Sohail Tanvir'),
#  (336008, 14, 'SA Asnodkar'),
#  (336008, 14, 'Sohail Tanvir'),
#  (336008, 14, 'M Rawat'),
#  (336008, 14, 'Sohail Tanvir'),
#  (336008, 14, 'Sohail Tanvir'),
#  (336008, 14, 'M Rawat'),
#  (336008, 15, 'Sohail Tanvir'),
#  (336008, 15, 'SK Trivedi'),
#  (336008, 15, 'M Rawat'),
#  (336008, 15, 'M Rawat'),
#  (336008, 15, 'M Rawat'),
#  (336008, 15, 'MM Patel'),
#  (336008, 16, 'SK Trivedi'),
#  (336008, 16, 'SK Trivedi'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 0, 'YV Takawale'),
#  (336008, 1, 'ST Jayasuriya'),
#  (336008, 1, 'ST Jayasuriya'),
#  (336008, 1, 'YV Takawale'),
#  (336008, 1, 'YV Takawale'),
#  (336008, 1, 'YV Takawale'),
#  (336008, 1, 'YV Takawale'),
#  (336008, 1, 'YV Takawale'),
#  (548379, 17, 'KA Pollard'),
#  (548379, 18, 'SL Malinga'),
#  (548379, 18, 'SL Malinga'),
#  (548379, 18, 'DS Kulkarni'),
#  (548379, 18, 'SL Malinga'),
#  (548379, 18, 'SL Malinga'),
#  (548379, 18, 'DS Kulkarni'),
#  (548379, 19, 'SL Malinga'),
#  (548379, 19, 'DS Kulkarni'),
#  (548379, 19, 'DS Kulkarni'),
#  (548379, 19, 'SL Malinga'),
#  (548379, 19, 'RP Singh'),
#  (548379, 19, 'DS Kulkarni'),
#  (548379, 13, 'Harbhajan Singh'),
#  (548379, 13, 'KA Pollard'),
#  (548379, 14, 'Harbhajan Singh'),
#  (548379, 14, 'Harbhajan Singh'),
#  (548379, 14, 'KA Pollard'),
#  (548379, 14, 'SL Malinga'),
#  (548379, 14, 'SL Malinga'),
#  (548379, 14, 'SL Malinga'),
#  (548379, 14, 'KA Pollard'),
#  (548379, 15, 'SL Malinga'),
#  (548379, 15, 'SL Malinga'),
#  (548379, 15, 'SL Malinga'),
#  (548379, 15, 'KA Pollard'),
#  (548379, 15, 'KA Pollard'),
#  (1216506, 16, 'DJ Hooda'),
#  (1216506, 16, 'JDS Neesham'),
#  (1216506, 16, 'DJ Hooda'),
#  (1216506, 17, 'JDS Neesham'),
#  (1216506, 17, 'DJ Hooda'),
#  (1216506, 17, 'DJ Hooda'),
#  (1216506, 17, 'DJ Hooda'),
#  (1216507, 10, 'SV Samson'),
#  (1216507, 10, 'R Parag'),
#  (1216507, 10, 'R Parag'),
#  (419158, 13, 'AC Voges'),
#  (1216507, 10, 'SV Samson'),
#  (419158, 13, 'AJ Finch'),
#  (1216507, 10, 'R Parag'),
#  (419158, 13, 'AS Raut'),
#  (1216507, 10, 'SV Samson'),
#  (419158, 13, 'AJ Finch'),
#  (1216507, 11, 'SV Samson'),
#  (419158, 14, 'AJ Finch'),
#  (1216507, 11, 'SV Samson'),
#  (419158, 14, 'AJ Finch'),
#  (1216507, 11, 'SV Samson'),
#  (419158, 14, 'P Dogra'),
#  (1216507, 11, 'R Parag'),
#  (419158, 14, 'P Dogra'),
#  (1216507, 11, 'SV Samson'),
#  (419158, 14, 'P Dogra'),
#  (1216507, 11, 'SV Samson'),
#  (419158, 14, 'P Dogra'),
#  (1216507, 12, 'R Parag'),
#  (419158, 15, 'AS Raut'),
#  (1216507, 12, 'R Tewatia'),
#  (419158, 14, 'SC Ganguly'),
#  (1216507, 12, 'R Tewatia'),
#  (419158, 14, 'SC Ganguly'),
#  (1216507, 12, 'R Tewatia'),
#  (419158, 14, 'SC Ganguly'),
#  (1216507, 12, 'R Parag'),
#  (419158, 14, 'CA Pujara'),
#  (1216507, 12, 'R Parag'),
#  (419158, 14, 'CA Pujara'),
#  (1216507, 12, 'R Parag'),
#  (419158, 14, 'SC Ganguly'),
#  (336007, 15, 'JA Morkel'),
#  (336007, 16, 'JA Morkel'),
#  (336007, 16, 'JA Morkel'),
#  (336007, 16, 'JA Morkel'),
#  (336007, 16, 'Joginder Sharma'),
#  (336007, 16, 'JA Morkel'),
#  (336007, 16, 'Joginder Sharma'),
#  (336007, 17, 'Joginder Sharma'),
#  (336007, 17, 'JA Morkel'),
#  (336007, 17, 'JA Morkel'),
#  (336007, 17, 'JA Morkel'),
#  (336007, 17, 'JA Morkel'),
#  (336007, 17, 'Joginder Sharma'),
#  (336007, 18, 'JA Morkel'),
#  (336007, 18, 'Joginder Sharma'),
#  (336007, 4, 'AC Gilchrist'),
#  (336007, 5, 'AC Gilchrist'),
#  (336007, 5, 'AC Gilchrist'),
#  (336007, 5, 'AC Gilchrist'),
#  (336007, 5, 'AC Gilchrist'),
#  (336007, 5, 'SB Styris'),
#  (336007, 5, 'AC Gilchrist'),
#  (336007, 6, 'SB Styris'),
#  (1216505, 6, 'D Padikkal'),
#  (1216505, 6, 'D Padikkal'),
#  (1216505, 6, 'AM Rahane'),
#  (1216505, 6, 'AM Rahane'),
#  (1216505, 6, 'S Dhawan'),
#  (1216505, 6, 'AM Rahane'),
#  (1216505, 6, 'AM Rahane'),
#  (1216505, 7, 'S Dhawan'),
#  (1216505, 7, 'S Dhawan'),
#  (1216505, 7, 'S Dhawan'),
#  (1216505, 7, 'AM Rahane'),
#  (1216505, 7, 'S Dhawan'),
#  (1216505, 7, 'S Dhawan'),
#  (1216505, 8, 'AM Rahane'),
#  (1216505, 8, 'S Dhawan'),
#  (1216505, 8, 'S Dhawan'),
#  (1216505, 8, 'AM Rahane'),
#  (1216505, 8, 'S Dhawan'),
#  (1216505, 8, 'S Dhawan'),
#  (1216505, 9, 'AM Rahane'),
#  (1216505, 9, 'S Dhawan'),
#  (1216505, 9, 'S Dhawan'),
#  (1216505, 9, 'AM Rahane'),
#  (1216505, 9, 'S Dhawan'),
#  (1216505, 9, 'S Dhawan'),
#  (1216505, 10, 'S Dhawan'),
#  (1216505, 10, 'AM Rahane'),
#  (1216505, 10, 'AM Rahane'),
#  (1216505, 10, 'S Dhawan'),
#  (1216505, 10, 'S Dhawan'),
#  (1216505, 10, 'S Dhawan'),
#  (1216505, 11, 'S Dhawan'),
#  (1216505, 11, 'AM Rahane'),
#  (1216505, 11, 'S Dhawan'),
#  (1216505, 11, 'S Dhawan'),
#  (1216505, 11, 'S Dhawan'),
#  (1216505, 11, 'AM Rahane'),
#  (1216505, 12, 'D Padikkal'),
#  (1216505, 12, 'V Kohli'),
#  (1216505, 12, 'AB de Villiers'),
#  (1216505, 12, 'AB de Villiers'),
#  (1216505, 12, 'D Padikkal'),
#  (1216505, 13, 'AB de Villiers'),
#  (1216505, 13, 'AB de Villiers'),
#  (1216505, 13, 'AB de Villiers'),
#  (1216505, 13, 'D Padikkal'),
#  (1216505, 13, 'D Padikkal'),
#  (1216505, 13, 'AB de Villiers'),
#  (1216505, 14, 'AB de Villiers'),
#  (1216505, 14, 'D Padikkal'),
#  (1216505, 14, 'AB de Villiers'),
#  (1216505, 14, 'AB de Villiers'),
#  (1216505, 14, 'D Padikkal'),
#  (1216505, 14, 'D Padikkal'),
#  (1216505, 14, 'D Padikkal'),
#  (419157, 7, 'KP Pietersen'),
#  (419157, 7, 'R Dravid'),
#  (419157, 7, 'R Dravid'),
#  (419157, 8, 'AT Rayudu'),
#  (419157, 8, 'AT Rayudu'),
#  (419157, 8, 'AT Rayudu'),
#  (419157, 8, 'AT Rayudu'),
#  (419157, 8, 'AT Rayudu'),
#  (419157, 9, 'AT Rayudu'),
#  (419157, 9, 'R McLaren'),
#  (419157, 9, 'AT Rayudu'),
#  (419157, 9, 'R McLaren'),
#  (419157, 9, 'AT Rayudu'),
#  (419157, 9, 'R McLaren'),
#  (419157, 10, 'AT Rayudu'),
#  (419157, 10, 'R McLaren'),
#  (419157, 10, 'AT Rayudu'),
#  (419157, 10, 'AT Rayudu'),
#  (419157, 10, 'AT Rayudu'),
#  (419157, 10, 'R McLaren'),
#  (419157, 11, 'AT Rayudu'),
#  (419157, 11, 'R McLaren'),
#  (419157, 11, 'AT Rayudu'),
#  (419157, 11, 'AT Rayudu'),
#  (419157, 11, 'AT Rayudu'),
#  (419157, 11, 'R McLaren'),
#  (419157, 12, 'R McLaren'),
#  (419157, 12, 'AT Rayudu'),
#  (419157, 12, 'AT Rayudu'),
#  (419157, 12, 'AT Rayudu'),
#  (419157, 12, 'AT Rayudu'),
#  (419157, 12, 'KA Pollard'),
#  (419157, 13, 'R McLaren'),
#  (419157, 13, 'R McLaren'),
#  (419157, 13, 'KA Pollard'),
#  (419157, 13, 'R McLaren'),
#  (419157, 13, 'R McLaren'),
#  (419157, 13, 'R McLaren'),
#  (419157, 13, 'R McLaren'),
#  (419157, 14, 'KA Pollard'),
#  (419157, 14, 'KA Pollard'),
#  (419157, 14, 'KA Pollard'),
#  (419157, 14, 'KA Pollard'),
#  (419157, 14, 'KA Pollard'),
#  (419157, 14, 'R McLaren'),
#  (419157, 14, 'KA Pollard'),
#  (419157, 15, 'KA Pollard'),
#  (419157, 15, 'JP Duminy'),
#  (419157, 15, 'R McLaren'),
#  (419157, 15, 'JP Duminy'),
#  (419157, 15, 'R McLaren'),
#  (419157, 15, 'JP Duminy'),
#  (419157, 16, 'R McLaren'),
#  (419157, 16, 'AM Nayar'),
#  (419157, 16, 'JP Duminy'),
#  (419157, 16, 'AM Nayar'),
#  (419157, 16, 'JP Duminy'),
#  (419157, 16, 'JP Duminy'),
#  (419157, 17, 'JP Duminy'),
#  (419157, 17, 'JP Duminy'),
#  (419157, 17, 'JP Duminy'),
#  (419157, 17, 'JP Duminy'),
#  (419157, 17, 'JP Duminy'),
#  (419157, 17, 'JP Duminy'),
#  (419157, 18, 'JP Duminy'),
#  (336007, 6, 'AC Gilchrist'),
#  (419157, 18, 'AM Nayar'),
#  (336007, 6, 'AC Gilchrist'),
#  (419157, 18, 'JP Duminy'),
#  (336007, 6, 'SB Styris'),
#  (419157, 18, 'JP Duminy'),
#  (336007, 6, 'SB Styris'),
#  (419157, 18, 'AM Nayar'),
#  (336007, 6, 'AC Gilchrist'),
#  (419157, 18, 'JP Duminy'),
#  (336007, 7, 'AC Gilchrist'),
#  (419157, 19, 'AM Nayar'),
#  (336007, 7, 'AC Gilchrist'),
#  (419157, 19, 'AM Nayar'),
#  (336007, 7, 'AC Gilchrist'),
#  (419157, 19, 'JP Duminy'),
#  (336007, 7, 'SB Styris'),
#  (419157, 19, 'JP Duminy'),
#  (336007, 7, 'SB Styris'),
#  (419157, 19, 'JP Duminy'),
#  (336007, 7, 'SB Styris'),
#  (419157, 19, 'AM Nayar'),
#  (336007, 7, 'AC Gilchrist'),
#  (419157, 13, 'LRPL Taylor'),
#  (829727, 0, 'S Dhawan'),
#  (829727, 0, 'S Dhawan'),
#  (829727, 13, 'EJG Morgan'),
#  (829727, 13, 'NV Ojha'),
#  (829727, 13, 'NV Ojha'),
#  (829727, 13, 'NV Ojha'),
#  (829727, 13, 'NV Ojha'),
#  (829727, 13, 'EJG Morgan'),
#  (829727, 14, 'NV Ojha'),
#  (829727, 14, 'RS Bopara'),
#  (829727, 14, 'RS Bopara'),
#  (829727, 14, 'RS Bopara'),
#  (829727, 14, 'EJG Morgan'),
#  (829727, 14, 'EJG Morgan'),
#  (829727, 15, 'RS Bopara'),
#  (829727, 15, 'RS Bopara'),
#  (829727, 15, 'EJG Morgan'),
#  (829727, 15, 'EJG Morgan'),
#  (548379, 10, 'MEK Hussey'),
#  (1082635, 11, 'A Mishra'),
#  (1216505, 14, 'D Padikkal'),
#  (829727, 15, 'EJG Morgan'),
#  (548379, 10, 'S Badrinath'),
#  (1082635, 11, 'A Mishra'),
#  (1216505, 15, 'AB de Villiers'),
#  (829727, 15, 'RS Bopara'),
#  (548379, 10, 'S Badrinath'),
#  (1082635, 12, 'A Mishra'),
#  (1216505, 15, 'AB de Villiers'),
#  (829727, 16, 'RS Bopara'),
#  (548379, 10, 'MEK Hussey'),
#  (1082635, 12, 'Z Khan'),
#  (1216505, 15, 'AB de Villiers'),
#  (829727, 16, 'EJG Morgan'),
#  (548379, 10, 'MEK Hussey'),
#  (1082635, 12, 'Z Khan'),
#  (548379, 11, 'S Badrinath'),
#  (548379, 11, 'S Badrinath'),
#  (548379, 11, 'S Badrinath'),
#  (548379, 11, 'S Badrinath'),
#  (548379, 11, 'S Badrinath'),
#  (548379, 11, 'MEK Hussey'),
#  (548379, 11, 'MEK Hussey'),
#  (548379, 12, 'S Badrinath'),
#  (1082635, 12, 'Z Khan'),
#  (1082635, 12, 'Z Khan'),
#  (1082635, 12, 'Z Khan'),
#  (1082635, 13, 'Z Khan'),
#  (1082635, 13, 'Z Khan'),
#  (1082635, 13, 'Z Khan'),
#  (1082635, 13, 'Z Khan'),
#  (1082635, 0, 'SS Iyer'),
#  (1082635, 0, 'KK Nair'),
#  (1082635, 0, 'SS Iyer'),
#  (1082635, 0, 'SS Iyer'),
#  (1082635, 1, 'SS Iyer'),
#  (1082635, 1, 'KK Nair'),
#  (1082635, 1, 'KK Nair'),
#  (1082635, 1, 'SS Iyer'),
#  (1082635, 1, 'SS Iyer'),
#  (1082635, 16, 'KA Pollard'),
#  (1082635, 16, 'KA Pollard'),
#  (1082635, 16, 'KA Pollard'),
#  (1082635, 16, 'HH Pandya'),
#  (1082635, 16, 'KA Pollard'),
#  (1082635, 16, 'KA Pollard'),
#  (1082635, 16, 'KA Pollard'),
#  (1082635, 17, 'HH Pandya'),
#  (1082635, 17, 'KA Pollard'),
#  (1082635, 17, 'HH Pandya'),
#  (1082635, 17, 'HH Pandya'),
#  (1082635, 17, 'KA Pollard'),
#  (1082635, 17, 'HH Pandya'),
#  (1082635, 17, 'KA Pollard'),
#  (1082635, 18, 'HH Pandya'),
#  (1082635, 18, 'HH Pandya'),
#  (1082635, 18, 'KA Pollard'),
#  (1082635, 18, 'HH Pandya'),
#  (1082635, 18, 'KA Pollard'),
#  (1082635, 18, 'HH Pandya'),
#  (1082635, 18, 'HH Pandya'),
#  (1082635, 19, 'KA Pollard'),
#  (1082635, 19, 'KA Pollard'),
#  (1082635, 19, 'HH Pandya'),
#  (1082635, 19, 'HH Pandya'),
#  (1082635, 19, 'HH Pandya'),
#  (1082635, 19, 'HH Pandya'),
#  (1082635, 19, 'HH Pandya'),
#  (1082635, 19, 'HH Pandya'),
#  (1082635, 0, 'SV Samson'),
#  (1082635, 0, 'KK Nair'),
#  (1082635, 7, 'PJ Cummins'),
#  (1082635, 7, 'PJ Cummins'),
#  (1082635, 7, 'PJ Cummins'),
#  (1082635, 7, 'MN Samuels'),
#  (1082635, 7, 'K Rabada'),
#  (1082635, 7, 'K Rabada'),
#  (1082635, 8, 'PJ Cummins'),
#  (1082635, 8, 'PJ Cummins'),
#  (1082635, 8, 'A Mishra'),
#  (1082635, 1, 'RR Pant'),
#  (1082635, 2, 'KK Nair'),
#  (1082635, 2, 'KK Nair'),
#  (1082635, 2, 'KK Nair'),
#  (1082635, 2, 'KK Nair'),
#  (1082635, 2, 'KK Nair'),
#  (1216505, 0, 'S Dhawan'),
#  (1216505, 1, 'PP Shaw'),
#  (1216505, 1, 'PP Shaw'),
#  (1216505, 1, 'PP Shaw'),
#  (1216505, 1, 'PP Shaw'),
#  (1216505, 1, 'PP Shaw'),
#  (1216505, 1, 'AM Rahane'),
#  (1216505, 2, 'S Dhawan'),
#  (1216505, 2, 'S Dhawan'),
#  (1216505, 2, 'S Dhawan'),
#  (1216505, 2, 'AM Rahane'),
#  (1216505, 2, 'S Dhawan'),
#  (1216505, 2, 'AM Rahane'),
#  (1216505, 3, 'S Dhawan'),
#  (1216505, 3, 'S Dhawan'),
#  (1216505, 3, 'S Dhawan'),
#  (1216505, 3, 'AM Rahane'),
#  (1216505, 3, 'AM Rahane'),
#  (1216505, 3, 'AM Rahane'),
#  (1216505, 4, 'AM Rahane'),
#  (1216505, 4, 'AM Rahane'),
#  (1216505, 4, 'AM Rahane'),
#  (1216505, 4, 'S Dhawan'),
#  (1216505, 4, 'AM Rahane'),
#  (1216505, 4, 'S Dhawan'),
#  (1216505, 5, 'S Dhawan'),
#  (1216505, 5, 'AM Rahane'),
#  (1216505, 5, 'AM Rahane'),
#  (1216505, 5, 'AM Rahane'),
#  (1216505, 5, 'AM Rahane'),
#  (1216505, 5, 'S Dhawan'),
#  (1216505, 6, 'S Dhawan'),
#  (1216505, 12, 'AM Rahane'),
#  (1216505, 13, 'AM Rahane'),
#  (1216505, 13, 'AM Rahane'),
#  (829727, 16, 'EJG Morgan'),
#  (829727, 16, 'A Ashish Reddy'),
#  (829727, 16, 'A Ashish Reddy'),
#  (829727, 16, 'RS Bopara'),
#  (829727, 17, 'RS Bopara'),
#  (829727, 17, 'RS Bopara'),
#  (829727, 17, 'RS Bopara'),
#  (829727, 17, 'A Ashish Reddy'),
#  (829727, 17, 'RS Bopara'),
#  (829727, 17, 'RS Bopara'),
#  (829727, 18, 'A Ashish Reddy'),
#  (829727, 18, 'RS Bopara'),
#  (829727, 18, 'RS Bopara'),
#  (829727, 18, 'RS Bopara'),
#  (829727, 18, 'RS Bopara'),
#  (829727, 18, 'A Ashish Reddy'),
#  (829727, 19, 'A Ashish Reddy'),
#  (829727, 19, 'A Ashish Reddy'),
#  (829727, 19, 'RS Bopara'),
#  (829727, 19, 'A Ashish Reddy'),
#  (829727, 19, 'RS Bopara'),
#  (829727, 19, 'A Ashish Reddy'),
#  (829727, 0, 'AM Rahane'),
#  (829727, 0, 'SV Samson'),
#  (829727, 0, 'SV Samson'),
#  (829727, 0, 'SV Samson'),
#  (829727, 0, 'AM Rahane'),
#  (829727, 0, 'AM Rahane'),
#  (829727, 1, 'SV Samson'),
#  (829727, 1, 'AM Rahane'),
#  (829727, 1, 'AM Rahane'),
#  (829727, 1, 'AM Rahane'),
#  (829727, 1, 'AM Rahane'),
#  (829727, 1, 'AM Rahane'),
#  (829727, 2, 'SV Samson'),
#  (829727, 2, 'SV Samson'),
#  (829727, 2, 'SV Samson'),
#  (829727, 2, 'SV Samson'),
#  (829727, 2, 'SV Samson'),
#  (829727, 2, 'AM Rahane'),
#  (829727, 3, 'SV Samson'),
#  (829727, 3, 'SV Samson'),
#  (829727, 3, 'AM Rahane'),
#  (829727, 3, 'AM Rahane'),
#  (829727, 3, 'AM Rahane'),
#  (829727, 3, 'AM Rahane'),
#  (419157, 13, 'V Kohli'),
#  (419157, 13, 'LRPL Taylor'),
#  (419157, 13, 'V Kohli'),
#  (419157, 13, 'LRPL Taylor'),
#  (419157, 14, 'V Kohli'),
#  (419157, 14, 'V Kohli'),
#  (419157, 14, 'V Kohli'),
#  (419157, 8, 'R Dravid'),
#  (419157, 8, 'R Dravid'),
#  (419157, 8, 'R Dravid'),
#  (419157, 8, 'KP Pietersen'),
#  (419157, 8, 'KP Pietersen'),
#  (419157, 8, 'R Dravid'),
#  (419157, 9, 'KP Pietersen'),
#  (419157, 9, 'RV Uthappa'),
#  (419157, 9, 'RV Uthappa'),
#  (419157, 9, 'KP Pietersen'),
#  (419157, 9, 'RV Uthappa'),
#  (419157, 9, 'KP Pietersen'),
#  (419157, 9, 'RV Uthappa'),
#  (419157, 10, 'KP Pietersen'),
#  (419157, 10, 'KP Pietersen'),
#  (419157, 10, 'RV Uthappa'),
#  (419157, 10, 'KP Pietersen'),
#  (419157, 10, 'LRPL Taylor'),
#  (419157, 10, 'RV Uthappa'),
#  (419157, 11, 'RV Uthappa'),
#  (419157, 11, 'LRPL Taylor'),
#  (419157, 11, 'V Kohli'),
#  (419157, 11, 'LRPL Taylor'),
#  (419157, 11, 'LRPL Taylor'),
#  (419157, 11, 'V Kohli'),
#  (419157, 12, 'V Kohli'),
#  (419157, 12, 'LRPL Taylor'),
#  (419157, 12, 'V Kohli'),
#  (419157, 12, 'LRPL Taylor'),
#  (419157, 12, 'V Kohli'),
#  (419157, 12, 'LRPL Taylor'),
#  (419157, 13, 'V Kohli'),
#  (419157, 14, 'LRPL Taylor'),
#  (419157, 14, 'V Kohli'),
#  (419157, 14, 'V Kohli'),
#  (419157, 15, 'V Kohli'),
#  (419158, 0, 'SR Watson'),
#  (419158, 0, 'SR Watson'),
#  (419158, 0, 'SR Watson'),
#  (419158, 0, 'NV Ojha'),
#  (419158, 0, 'NV Ojha'),
#  (419158, 0, 'SR Watson'),
#  (419158, 1, 'NV Ojha'),
#  (419158, 1, 'NV Ojha'),
#  (419158, 2, 'SR Watson'),
#  (419158, 2, 'SR Watson'),
#  (419158, 2, 'NV Ojha'),
#  (419158, 2, 'NV Ojha'),
#  (419158, 2, 'NV Ojha'),
#  (419158, 2, 'SR Watson'),
#  (336008, 2, 'YK Pathan'),
#  (336008, 2, 'YK Pathan'),
#  (336008, 2, 'SA Asnodkar'),
#  (336008, 2, 'SA Asnodkar'),
#  (336008, 3, 'YK Pathan'),
#  (336008, 3, 'SR Watson'),
#  (336008, 3, 'SR Watson'),
#  (336008, 3, 'SR Watson'),
#  (336008, 1, 'SA Asnodkar'),
#  (336008, 1, 'SA Asnodkar'),
#  (336008, 1, 'SA Asnodkar'),
#  (336008, 2, 'GC Smith'),
#  (336008, 2, 'GC Smith'),
#  (336008, 4, 'SR Watson'),
#  (336008, 4, 'SA Asnodkar'),
#  (336008, 4, 'SA Asnodkar'),
#  (336008, 5, 'SR Watson'),
#  (336008, 5, 'SR Watson'),
#  (336008, 5, 'SR Watson'),
#  (336008, 5, 'SR Watson'),
#  (336008, 5, 'SA Asnodkar'),
#  (336008, 3, 'SR Watson'),
#  (336008, 3, 'SR Watson'),
#  (336008, 4, 'SR Watson'),
#  (336008, 4, 'SR Watson'),
#  (336008, 4, 'SA Asnodkar'),
#  (336008, 0, 'GC Smith'),
#  (419158, 3, 'NV Ojha'),
#  (336008, 12, 'SK Warne'),
#  (419158, 3, 'NV Ojha'),
#  (336008, 12, 'SK Warne'),
#  (419158, 3, 'NV Ojha'),
#  (336008, 12, 'SK Warne'),
#  (419158, 3, 'NV Ojha'),
#  (336007, 7, 'AC Gilchrist'),
#  (336007, 8, 'AC Gilchrist'),
#  (336007, 8, 'AC Gilchrist'),
#  ...]

# %%
# test

query = '''select a.batsman, a.runs/b.dismissals as average
from (select batsman, SUM(batsman_runs) as runs from ipl_ball_by_ball
group by batsman) a
JOIN (select batsman, count(player_dismissed) as dismissals from ipl_ball_by_ball
where player_dismissed != 'NA'
group by batsman
) b
ON a.batsman == b.batsman
order by average desc
LIMIT 10'''

c.execute(query)
c.fetchall()
# Out:
# Out[10]: [('Iqbal Abdulla', 88),
#  ('RD Gaikwad', 68),
#  ('MN van Wyk', 55),
#  ('PD Collingwood', 50),
#  ('HM Amla', 44),
#  ('LH Ferguson', 44),
#  ('AB de Villiers', 42),
#  ('KL Rahul', 42),
#  ('CH Gayle', 41),
#  ('DA Warner', 41)]

# %%
# test

import json
c.execute(query)
json_output = json.dumps(c.fetchall())
json_output
# Out:
# Out[11]: '[["Iqbal Abdulla", 88], ["RD Gaikwad", 68], ["MN van Wyk", 55], ["PD Collingwood", 50], ["HM Amla", 44], ["LH Ferguson", 44], ["AB de Villiers", 42], ["KL Rahul", 42], ["CH Gayle", 41], ["DA Warner", 41]]'

# %%
import json
# Importing json which will be used to convert results to json object

class Table:
      
    def __init__(self, query):
        '''
        Constructor for the class. Connects to the sqlite databse and receives the query.
        '''
        self.query = query
        
        conn = sqlite3.connect("ipl.db")
        c = conn.cursor()
        
    def get_result(self):
        '''
        Executes the query and returns the result 
        in form of json object.
        '''
        try: 
            c.execute(self.query)
            json_output = json.dumps(c.fetchall())
            return json_output
        except Exception:
              print("Your query did not run")
     
    @staticmethod
    def get_status():
        '''
        Checks the connection to the database. Returns boolean values.
        '''
        try:
            conn.cursor()
            return True
        except Exception as ex:
            return False

# %%
query1 = '''select a.batsman, a.runs/b.dismissals as average
            from (select batsman, SUM(batsman_runs) as runs from ipl_ball_by_ball
            group by batsman) a
            JOIN (select batsman, count(player_dismissed) as dismissals from ipl_ball_by_ball
            where player_dismissed != 'NA'
            group by batsman
            ) b
            ON a.batsman == b.batsman
            order by average desc
            LIMIT 10'''

q1 = Table(query1)

print(q1.get_result())
# Out:
# [["Iqbal Abdulla", 88], ["RD Gaikwad", 68], ["MN van Wyk", 55], ["PD Collingwood", 50], ["HM Amla", 44], ["LH Ferguson", 44], ["AB de Villiers", 42], ["KL Rahul", 42], ["CH Gayle", 41], ["DA Warner", 41]]
